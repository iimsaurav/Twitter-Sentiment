# %% [markdown]
# **Installing all the dependencies**

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# ...
#      |████████████████████████████████| 133kB 1.5MB/s
# ...

# %% [markdown]
# **Importing dependencies**

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# <br>Importing tweets from twitter through API (Application Interface Protocol) </br>
# Signup on *'https://developer.twitter.com/'* for API Authentication Variables.

# %%
#My Twitter API Authentication Variables
consumer_key = ' '
consumer_secret = ' '
access_token = ' '
access_token_secret = ' '

# %% [markdown]
# Imporing Tweets

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)


tweets = api.search('Data', count=50)



data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(2000))


print(tweets[0].created_at)
# Out:
#                                                Tweets
# 0   RT @xerneasbangtan: you wanna see how successf...
# 1   로라 던, 부모가 못 이룬 ´오스카 꿈´ 이뤘다... ´결혼이야기´로 여우조연상 수...
# 2   Interesante! Calculadora del valor de la data\...
# 3   RT @melstonemusic: data said “trans rights” ht...
# 4   RT @fachevrand7: minha bio tá tão sem graça, f...
# 5   RT @vladimirpadrino: La @ArmadaFANB ha recuper...
# 6   RT @MudandoVidas5: Relógio digital - Relógio p...
# 7   RT @iMeluny: GDPR applies to private sector &a...
# 8   RT @nookyelur: 3/ The author - Tzach Yoked - c...
# 9   RT @UpdatesHL: 📈| Entradas en solitario de los...
# 10  RT @haiarm: 우한폐렴 묻자… ˝정치적 질문˝ 강제 탈퇴시킨 친문 맘카페\n...
# 11  RT @BeholdIsrael: Data from https://t.co/QR905...
# 12  Trump promised to eliminate the deficit in eig...
# 13  @MichaelGLFlood That's absolutely the quality ...
# 14  RT @kamarusk: @hamsanandi @doubtinggaurav Most...
# 15  @RickAutoMax @Colecaine8 @realDonaldTrump http...
# ...

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\mrsau\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(50))
# Out:
#                                                Tweets  \
# 0   RT @xerneasbangtan: you wanna see how successf...
# 1   로라 던, 부모가 못 이룬 ´오스카 꿈´ 이뤘다... ´결혼이야기´로 여우조연상 수...
# 2   Interesante! Calculadora del valor de la data\...
# 3   RT @melstonemusic: data said “trans rights” ht...
# 4   RT @fachevrand7: minha bio tá tão sem graça, f...
# 5   RT @vladimirpadrino: La @ArmadaFANB ha recuper...
# 6   RT @MudandoVidas5: Relógio digital - Relógio p...
# 7   RT @iMeluny: GDPR applies to private sector &a...
# 8   RT @nookyelur: 3/ The author - Tzach Yoked - c...
# 9   RT @UpdatesHL: 📈| Entradas en solitario de los...
# 10  RT @haiarm: 우한폐렴 묻자… ˝정치적 질문˝ 강제 탈퇴시킨 친문 맘카페\n...
# 11  RT @BeholdIsrael: Data from https://t.co/QR905...
# 12  Trump promised to eliminate the deficit in eig...
# 13  @MichaelGLFlood That's absolutely the quality ...
# 14  RT @kamarusk: @hamsanandi @doubtinggaurav Most...
# 15  @RickAutoMax @Colecaine8 @realDonaldTrump http...
# ...
